# %%
# Displays figures in line
# %matplotlib inline

# Import dependencies 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests 
import json
plt.style.use('ggplot')

from pprint import pprint

# %%
url = "https://maps2.dcgis.dc.gov/dcgis/rest/services/DCGIS_DATA/Public_Safety_WebMercator/MapServer/24/query?where=1%3D1&outFields=*&outSR=4326&f=json"

# %%
response = requests.get(url).json()

# %%
data = response['features']
crash_data = []

# %%
for t in range(184):
    i = 0
    for x in data:
        crash_data.append(data[i]['attributes'])
        i = i + 1

# %%
master_df = pd.DataFrame(crash_data)
master_df
# Out:
#                                                   ADDRESS  BICYCLISTSIMPAIRED  \
# 0                                    500 NORTH CAPITOL ST                   0
# 1                               I295N/PENNSYLVANIA AVE SE                   0
# 2                          1ST ST NW & GALLATIN ST NW\r\n                   0
# 3       UNIT BLOCK OF NEW YORK AVENUE NE. & 13OO BLOCK...                   0
# 4                                            2819 M ST NW                   0
# 5                                        3300 M STREET NW                   0
# 6                                          6622 5TH ST NW                   0
# 7                                  4201 GEORGIA AVENUE NW                   0
# 8                    NEW YORK AVENUE NW & M STREET NW\r\n                   0
# 9                                          100 14TH ST NW                   0
# 10                                1810 ADAMS MILL ROAD NW                   0
# ...

# %%
#Line graph indicating total number of accidents over time (by accident type)
bike_df = master_df[["ADDRESS", "CRIMEID", "FATAL_BICYCLIST", "FROMDATE", "LATITUDE", "LONGITUDE", "MAJORINJURIES_BICYCLIST", "MINORINJURIES_BICYCLIST", "XCOORD", "YCOORD"]]
bike_df_reduced = bike_df.loc[(bike_df["MAJORINJURIES_BICYCLIST"] >= 1) | (bike_df["MINORINJURIES_BICYCLIST"]>= 1) | (bike_df["FATAL_BICYCLIST"]>= 1), :]
bike_df_reduced.head()
# Out:
#                               ADDRESS   CRIMEID  FATAL_BICYCLIST  \
# 144  17TH STREET NW & K STREET NW\r\n  27226932                0
# 152                   200 23RD ST, NW  27226944                0
# 210              14TH ST NW / T ST NW  25128741                0
# 275                   659 G STREET NE  27672923                0
# 394               3420 14TH STREET NW  27227857                0
#
#           FROMDATE   LATITUDE  LONGITUDE  MAJORINJURIES_BICYCLIST  \
# 144  1487721600000  38.902524 -77.038510                        0
# 152  1487721600000  38.892713 -77.050304                        0
# 210  1396396800000  38.915569 -77.031937                        0
# 275  1525996800000  38.898909 -76.996493                        0
# 394  1487808000000  38.932247 -77.033063                        0
#
#      MINORINJURIES_BICYCLIST      XCOORD      YCOORD
# 144                        1  396659.650  137186.153
# 152                        1  395650.006  136097.471
# ...

# %%
vehicle_df = master_df[["ADDRESS", "CRIMEID", "FATAL_DRIVER", "FROMDATE", "LATITUDE", "LONGITUDE", "MAJORINJURIES_DRIVER", "MINORINJURIES_DRIVER", "XCOORD", "YCOORD"]]
vehicle_df_reduced = vehicle_df.loc[(vehicle_df["MAJORINJURIES_DRIVER"] >= 1) | (vehicle_df["MINORINJURIES_DRIVER"]>= 1) | (vehicle_df["FATAL_DRIVER"]>= 1), :]
vehicle_df_reduced.head()
# Out:
#                                  ADDRESS   CRIMEID  FATAL_DRIVER  \
# 7                 4201 GEORGIA AVENUE NW  27227671             0
# 8   NEW YORK AVENUE NW & M STREET NW\r\n  27227677             0
# 11                     900 7TH STREET NW  26907568             0
# 21                    2100 2ND STREET NW  27227749             0
# 24               50 MASSACHUSETTS AVE NE  24606315             0
#
#          FROMDATE   LATITUDE  LONGITUDE  MAJORINJURIES_DRIVER  \
# 7   1487808000000  38.942738 -77.025788                     0
# 8   1487808000000  38.905712 -77.013359                     0
# 11  1460246400000  38.901592 -77.022711                     0
# 21  1487808000000  38.918868 -77.014919                     0
# 24  1369094400000  38.897539 -77.006179                     1
#
#     MINORINJURIES_DRIVER      XCOORD      YCOORD
# 7                      1  397768.715  141650.736
# 8                      1  398846.296  137545.343
# 11                     1  398030.004  137082.234
# ...
