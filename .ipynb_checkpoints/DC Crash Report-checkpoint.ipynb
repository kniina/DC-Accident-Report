# %%
# !pip install python-dateutil
# Displays figures in line
# %matplotlib inline

# Import dependencies 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests 
import json
import locale
import datetime
plt.style.use('ggplot')

from datetime import datetime
from pprint import pprint
from dateutil.parser import parse
# Out:
# ...
# distributed 1.21.8 requires msgpack, which is not installed.

# %%
url = "https://maps2.dcgis.dc.gov/dcgis/rest/services/DCGIS_DATA/Public_Safety_WebMercator/MapServer/24/query?where=1%3D1&outFields=*&outSR=4326&f=json"

# %%
response = requests.get(url).json()

# %%
data = response['features']
crash_data = []

# %%
for t in range(185):
    i = 0
    for x in data:
        crash_data.append(data[i]['attributes'])
        i = i + 1

# %%
master_df = pd.DataFrame(crash_data)
master_df.head()
# Out:
#                                 ADDRESS  BICYCLISTSIMPAIRED       CCN  \
# 0                  110 IRVING STREET NW                   0  14058198
# 1               800 CONSTITUTION AVE NW                   0  12099906
# 2          900 BLOCK OF  7TH STREET  NW                   0  11179091
# 3   8TH ST NW and  NEW HAMPSHIRE AVE NW                   0  14057254
# 4  3700 MARTIN LUTHER KING JR AVENUE SE                   0  12100393
#
#     CRIMEID  DRIVERSIMPAIRED                                 EVENTID  \
# 0  25153246                0  {E809D7D3-017B-4CD2-B976-F74D0F579F56}
# 1  24104674                0  {AE1E4C9D-3125-4118-A7FE-91AA63F8B0F6}
# 2  26649213                0  {D40F4527-2130-40FD-8767-5A1C02C73465}
# 3  25153265                0  {E056E3ED-1322-4743-9228-F40AD49C7545}
# 4  24104690                0  {9339CFCC-7422-4E85-96D4-FB566164D4C7}
#
#    FATAL_BICYCLIST  FATAL_DRIVER  FATAL_PEDESTRIAN       FROMDATE     ...      \
# ...

# %%
#Create bike only dataframe
bike_df = master_df[["ADDRESS", "CRIMEID", "FATAL_BICYCLIST", "FROMDATE", "LATITUDE", "LONGITUDE", "MAJORINJURIES_BICYCLIST", "MINORINJURIES_BICYCLIST", "XCOORD", "YCOORD"]]
bike_df_reduced = bike_df.loc[(bike_df["MAJORINJURIES_BICYCLIST"] >= 1) | (bike_df["MINORINJURIES_BICYCLIST"]>= 1) | (bike_df["FATAL_BICYCLIST"]>= 1), :]
bike_df["MAJORINJURIES_BICYCLIST"].sum()
# Out:
# 185

# %%
#Create vehicle only dataframe
vehicle_df = master_df[["ADDRESS", "CRIMEID", "FATAL_DRIVER", "FROMDATE", "LATITUDE", "LONGITUDE", "MAJORINJURIES_DRIVER", "MINORINJURIES_DRIVER", "XCOORD", "YCOORD"]]
vehicle_df_reduced = vehicle_df.loc[(vehicle_df["MAJORINJURIES_DRIVER"] >= 1) | (vehicle_df["MINORINJURIES_DRIVER"]>= 1) | (vehicle_df["FATAL_DRIVER"]>= 1), :]
vehicle_df.head()
# Out:
#                                 ADDRESS   CRIMEID  FATAL_DRIVER  \
# 0                  110 IRVING STREET NW  25153246             0
# 1               800 CONSTITUTION AVE NW  24104674             0
# 2          900 BLOCK OF  7TH STREET  NW  26649213             0
# 3   8TH ST NW and  NEW HAMPSHIRE AVE NW  25153265             0
# 4  3700 MARTIN LUTHER KING JR AVENUE SE  24104690             0
#
#         FROMDATE   LATITUDE  LONGITUDE  MAJORINJURIES_DRIVER  \
# 0  1398470400000  38.929652 -77.015648                     0
# 1  1342483200000  38.892223 -76.994573                     0
# 2  1323216000000  38.902312 -77.021917                     0
# 3  1398384000000  38.937970 -77.023076                     0
# 4  1342569600000  38.837547 -77.006113                     0
#
#    MINORINJURIES_DRIVER      XCOORD      YCOORD
# 0                     0  398679.411  140224.947
# 1                     1  400470.892  136018.501
# 2                     1  398098.921  137162.090
# ...

# %%
#Create pedestrian only dataframe
pedest_df = master_df[["ADDRESS", "CRIMEID", "FATAL_PEDESTRIAN", "FROMDATE", "LATITUDE", "LONGITUDE", "MAJORINJURIES_PEDESTRIAN", "MINORINJURIES_PEDESTRIAN", "XCOORD", "YCOORD"]]

pedest_df_reduced = pedest_df.loc[(pedest_df["MAJORINJURIES_PEDESTRIAN"] >= 1) | (pedest_df["MINORINJURIES_PEDESTRIAN"] >= 1) | (pedest_df["FATAL_PEDESTRIAN"] >= 1),:]
pedest_df.head()
# Out:
#                                 ADDRESS   CRIMEID  FATAL_PEDESTRIAN  \
# 0                  110 IRVING STREET NW  25153246                 0
# 1               800 CONSTITUTION AVE NW  24104674                 0
# 2          900 BLOCK OF  7TH STREET  NW  26649213                 0
# 3   8TH ST NW and  NEW HAMPSHIRE AVE NW  25153265                 0
# 4  3700 MARTIN LUTHER KING JR AVENUE SE  24104690                 0
#
#         FROMDATE   LATITUDE  LONGITUDE  MAJORINJURIES_PEDESTRIAN  \
# 0  1398470400000  38.929652 -77.015648                         0
# 1  1342483200000  38.892223 -76.994573                         0
# 2  1323216000000  38.902312 -77.021917                         0
# 3  1398384000000  38.937970 -77.023076                         0
# 4  1342569600000  38.837547 -77.006113                         0
#
#    MINORINJURIES_PEDESTRIAN      XCOORD      YCOORD
# 0                         0  398679.411  140224.947
# 1                         0  400470.892  136018.501
# ...

# %%
pedest_df.dtypes
# Out:
# ADDRESS                      object
# CRIMEID                       int64
# FATAL_PEDESTRIAN              int64
# FROMDATE                      int64
# LATITUDE                    float64
# LONGITUDE                   float64
# MAJORINJURIES_PEDESTRIAN      int64
# MINORINJURIES_PEDESTRIAN      int64
# XCOORD                      float64
# YCOORD                      float64
# dtype: object

# %%
#Convert 'FROMDATE' column into date format
bike_df["FROMDATE"]=pd.to_datetime(bike_df['FROMDATE'],unit='ms')

vehicle_df["FROMDATE"]=pd.to_datetime(vehicle_df["FROMDATE"],unit='ms')

pedest_df["FROMDATE"]=pd.to_datetime(pedest_df['FROMDATE'],unit='ms')
bike_df
# Out:
# C:\Users\jpaz5\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\jpaz5\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\jpaz5\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#List only the years for bike data in the last column

bike_df["YEAR"]=pd.DatetimeIndex(bike_df["FROMDATE"]).year
bike_df
# Out:
# C:\Users\jpaz5\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                            ADDRESS   CRIMEID  FATAL_BICYCLIST  \
# 0                             110 IRVING STREET NW  25153246                0
# 1                          800 CONSTITUTION AVE NW  24104674                0
# 2                     900 BLOCK OF  7TH STREET  NW  26649213                0
# 3              8TH ST NW and  NEW HAMPSHIRE AVE NW  25153265                0
# 4             3700 MARTIN LUTHER KING JR AVENUE SE  24104690                0
# 5                               900 17TH STREET NW  25153273                0
# ...

# %%
#List only the years for vehicle data in the last column

vehicle_df["YEAR"]=pd.DatetimeIndex(vehicle_df["FROMDATE"]).year
vehicle_df.head()
# Out:
# C:\Users\jpaz5\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                 ADDRESS   CRIMEID  FATAL_DRIVER   FROMDATE  \
# 0                  110 IRVING STREET NW  25153246             0 2014-04-26
# 1               800 CONSTITUTION AVE NW  24104674             0 2012-07-17
# 2          900 BLOCK OF  7TH STREET  NW  26649213             0 2011-12-07
# 3   8TH ST NW and  NEW HAMPSHIRE AVE NW  25153265             0 2014-04-25
# 4  3700 MARTIN LUTHER KING JR AVENUE SE  24104690             0 2012-07-18
#
#     LATITUDE  LONGITUDE  MAJORINJURIES_DRIVER  MINORINJURIES_DRIVER  \
# ...

# %%
#List only the years for pedestrian data in the last column

pedest_df["YEAR"]=pd.DatetimeIndex(pedest_df["FROMDATE"]).year
pedest_df
# Out:
# C:\Users\jpaz5\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                            ADDRESS   CRIMEID  \
# 0                             110 IRVING STREET NW  25153246
# 1                          800 CONSTITUTION AVE NW  24104674
# 2                     900 BLOCK OF  7TH STREET  NW  26649213
# 3              8TH ST NW and  NEW HAMPSHIRE AVE NW  25153265
# 4             3700 MARTIN LUTHER KING JR AVENUE SE  24104690
# 5                               900 17TH STREET NW  25153273
# 6                                      100 M ST NE  25153356
# ...

# %%
#aggregate table of #of minor and major injuries + fatalities
bike_agg = bike_df_reduced.groupby(["YEAR"])[['MINORINJURIES_BICYCLIST','MAJORINJURIES_BICYCLIST','FATAL_BICYCLIST']].sum()
bike_agg
# Out:
#       MINORINJURIES_BICYCLIST  MAJORINJURIES_BICYCLIST  FATAL_BICYCLIST
# YEAR
# 2013                      185                        0                0
# 2016                      185                        0                0
# 2017                        0                      185                0
# 2018                     1665                        0                0

# %%
#aggregate table of #of minor and major injuries + fatalities
vehicle_agg = vehicle_df_reduced.groupby(["YEAR"])[['MINORINJURIES_DRIVER','MAJORINJURIES_DRIVER','FATAL_DRIVER']].sum()
vehicle_agg
# Out:
#       MINORINJURIES_DRIVER  MAJORINJURIES_DRIVER  FATAL_DRIVER
# YEAR
# 2011                  1665                  1295             0
# 2012                  1295                   925             0
# 2013                  1850                  3330             0
# 2014                  1295                  1480             0
# 2015                  2405                     0             0
# 2016                   370                     0             0
# 2017                  1480                     0             0
# 2018                 18500                   925           185

# %%
#aggregate table of #of minor and major injuries + fatalities
pedest_agg = pedest_df_reduced.groupby(["YEAR"])[['MINORINJURIES_PEDESTRIAN','MAJORINJURIES_PEDESTRIAN','FATAL_PEDESTRIAN']].sum()
pedest_agg
# Out:
#       MINORINJURIES_PEDESTRIAN  MAJORINJURIES_PEDESTRIAN  FATAL_PEDESTRIAN
# YEAR
# 2014                       185                         0                 0
# 2015                       185                         0                 0
# 2017                       185                         0                 0
# 2018                      4070                       370                 0

# %%
#Create bar chart
yearData = {"Year: ["2010","2011","2012","2013","2014","2015","2016","2017","2018"],
           "Total Injuries Pedest":
           }
# Out:
#   File "<ipython-input-18-81269fc90fbc>", line 2
#     yearData = {"Year: ["2010","2011","2012","2013","2014","2015","2016","2017","2018"],
#                             ^
# SyntaxError: invalid syntax
