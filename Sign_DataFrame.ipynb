# %%
import pandas as pd
import gmaps
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
file = "sign_data.csv"
sign_data = pd.read_csv(file, encoding="ISO-8859-1")
sign_data.head()
# Out:
#            X          Y  OBJECTID         SIGNID         POLEID  BARCODEID  \
# 0 -77.018860  38.912504         1  1.368068e-320  1.223801e-320       2769
# 1 -77.018996  38.912516         2  1.368562e-320  1.224295e-320       2770
# 2 -77.018996  38.912516         3  1.369056e-320  1.224295e-320       2771
# 3 -77.019012  38.912557         4  1.369550e-320  1.224789e-320       2772
# 4 -77.019012  38.912557         5  1.370044e-320  1.224789e-320       2773
#
#    EQUIPMENTID  SIGNTYPE SIGNNAME                       Signal     ...       \
# 0         2769         3     R1-1                         Stop     ...
# 1         2770        11     W4-4  Cross Traffic Does Not Stop     ...
# 2         2771         3     R1-1                         Stop     ...
# 3         2772         1    R6-1R                      One Way     ...
# 4         2773         1    R6-1L                      One Way     ...
#
#   SHEETING  SUPPORTDETAILS  DIRECTION  VISIBILITY  SIGNCONDITION  COMMENTS  \
# ...

# %%
sign_data.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'SIGNID', 'POLEID', 'BARCODEID', 'EQUIPMENTID',
#        'SIGNTYPE', 'SIGNNAME', 'Signal', 'SIGNSIZE', 'SIGNHEIGHT', 'SHEETING',
#        'SUPPORTDETAILS', 'DIRECTION', 'VISIBILITY', 'SIGNCONDITION',
#        'COMMENTS', 'PICTUREPATH', 'PICTURE', 'XCOORD', 'YCOORD'],
#       dtype='object')

# %%
organized_sign_data = sign_data[["X", "Y", "SIGNNAME", "Signal", "VISIBILITY", "SIGNCONDITION", "XCOORD", "YCOORD"]]
organized_sign_data.head()
# Out:
#            X          Y SIGNNAME                       Signal  VISIBILITY  \
# 0 -77.018860  38.912504     R1-1                         Stop         1.0
# 1 -77.018996  38.912516     W4-4  Cross Traffic Does Not Stop         1.0
# 2 -77.018996  38.912516     R1-1                         Stop         1.0
# 3 -77.019012  38.912557    R6-1R                      One Way         1.0
# 4 -77.019012  38.912557    R6-1L                      One Way         1.0
#
#    SIGNCONDITION       XCOORD       YCOORD
# 0            1.0  398364.4549  138292.6537
# 1            1.0  398352.7394  138293.9543
# 2            1.0  398352.7394  138293.9543
# 3            1.0  398351.2853  138298.5566
# 4            1.0  398351.2853  138298.5566

# %%
locations = organized_sign_data[["Y", "X"]]
fig = gmaps.figure()
markers = gmaps.marker_layer(locations)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
